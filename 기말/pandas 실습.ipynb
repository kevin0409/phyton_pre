# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
data = pd.read_csv('./Life_expectancy.csv')

# %%
pip install missingno --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting missingno
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: matplotlib in /private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages (from missingno) (3.4.0.dev7898+g7b3c98d3e)
# Collecting seaborn
#   Using cached seaborn-0.12.1-py3-none-any.whl (288 kB)
# Collecting scipy
#   Using cached scipy-1.9.3.tar.gz (42.1 MB)
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/cli/base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/cli/req_command.py", line 205, in wrapper
#     return func(self, options, args)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/commands/install.py", line 341, in run
#     requirement_set = resolver.resolve(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
#     return any(self)
# [notice] To update, run: pip install --upgrade pip
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 215, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 291, in __init__
#     super().__init__(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 161, in __init__
#     self.dist = self._prepare()
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 230, in _prepare
#     dist = self._prepare_distribution()
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 302, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 428, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 497, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 58, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/distributions/sdist.py", line 61, in prepare_distribution_metadata
#     self.req.prepare_metadata()
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/req/req_install.py", line 526, in prepare_metadata
#     self.metadata_directory = generate_metadata(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/operations/build/metadata.py", line 35, in generate_metadata
#     distinfo_dir = backend.prepare_metadata_for_build_wheel(metadata_dir)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_internal/utils/misc.py", line 706, in prepare_metadata_for_build_wheel
#     return super().prepare_metadata_for_build_wheel(
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/pep517/wrappers.py", line 188, in prepare_metadata_for_build_wheel
#     return self._call_hook('prepare_metadata_for_build_wheel', {
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/pep517/wrappers.py", line 332, in _call_hook
#     raise BackendUnavailable(data.get('traceback', ''))
# pip._vendor.pep517.wrappers.BackendUnavailable: Traceback (most recent call last):
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 89, in _build_backend
#     obj = import_module(mod_path)
#   File "/private/var/containers/Bundle/Application/ACD75854-329C-430F-9651-792E352648C9/Carnets.app/Library/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 984, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'mesonpy'
# Note: you may need to restart the kernel to use updated packages.

# %%
data.shape
# Out:
# (2938, 22)

# %%
data.tail(10)
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 2928  Zimbabwe  2009  Developing             50.0            587.0
# 2929  Zimbabwe  2008  Developing             48.2            632.0
# 2930  Zimbabwe  2007  Developing             46.6             67.0
# 2931  Zimbabwe  2006  Developing             45.4              7.0
# 2932  Zimbabwe  2005  Developing             44.6            717.0
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 2928             30     4.64                1.040021         73.0      853
# 2929             30     3.56               20.843429         75.0        0
# 2930             29     3.88               29.814566         72.0      242
# 2931             28     4.57               34.262169         68.0      212
# 2932             28     4.14                8.717409         65.0      420
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  \
# 2928  ...   69.0               6.26         73.0      18.1   65.824121
# 2929  ...   75.0               4.96         75.0      20.5  325.678573
# 2930  ...   73.0               4.47         73.0      23.7  396.998217
# 2931  ...   71.0               5.12          7.0      26.8  414.796232
# 2932  ...   69.0               6.44         68.0      30.3  444.765750
# 2933  ...   67.0               7.13         65.0      33.6  454.366654
# 2934  ...    7.0               6.52         68.0      36.7  453.351155
# 2935  ...   73.0               6.53         71.0      39.8   57.348340
# 2936  ...   76.0               6.16         75.0      42.1  548.587312
# 2937  ...   78.0               7.10         78.0      43.5  547.358878
#
#       Population  Thinness 1-19 years  Thinness 5-9 years  \
# 2928   1381599.0                  7.5                 7.4
# 2929  13558469.0                  7.8                 7.8
# 2930   1332999.0                  8.2                 8.2
# 2931  13124267.0                  8.6                 8.6
# 2932    129432.0                  9.0                 9.0
# 2933  12777511.0                  9.4                 9.4
# 2934  12633897.0                  9.8                 9.9
# 2935    125525.0                  1.2                 1.3
# 2936  12366165.0                  1.6                 1.7
# 2937  12222251.0                 11.0                11.2
#
#       Income composition of resources  Schooling
# 2928                            0.419        9.9
# 2929                            0.421        9.7
# 2930                            0.414        9.6
# 2931                            0.408        9.5
# 2932                            0.406        9.3
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [10 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'Thinness 1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
np.unique(data['Status'], return_counts = True)
# Out:
# (array(['Developed', 'Developing'], dtype=object), array([ 512, 2426]))

# %%
data.describe()
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#                BMI  Under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        Thinness 1-19 years  Thinness 5-9 years  \
# count          2904.000000         2904.000000
# mean              4.839704            4.870317
# std               4.420195            4.508882
# min               0.100000            0.100000
# 25%               1.600000            1.500000
# 50%               3.300000            3.300000
# 75%               7.200000            7.200000
# max              27.700000           28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
pip update missingno
# Out:
# ERROR: unknown command "update"
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'
